# %%
import weave
assert weave.__version__ >= "0.50.14", "Please upgrade weave!" 
from weave.trace.env import _wandb_api_key_via_netrc

from tqdm import tqdm
from collections import defaultdict

import pandas as pd

import altair as alt

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import os

import multiprocessing
from multiprocessing.pool import ThreadPool
import subprocess
import tempfile
import sys

import requests
from requests.auth import HTTPBasicAuth
import json

selected_metrics = ["StrLenScorer", "KolmogorovComplexity", "KolmogorovComplexityNormalized", "MissingTopicScorer", "FleshReadingScorer", "TopicConsistency", "NamedEntityDensity", "GoldenDescriptionROUGEScorer", 'GoldenDescriptionCosineTFIDFScorer', 'GoldenDescriptionBLEUScorer']

# Define weave project ID and initialize weave client
project_id = "highly-biased/final_reevaluation"

client = weave.init(project_id)
calls = client.server.calls_query_stream({
   "project_id": project_id,
   "filter": {"trace_roots_only": True},
   "sort_by": [{"field":"started_at","direction":"desc"}],
})
calls = client.get_calls(
    filter={"call_ids":[call.id for call in calls]},
)
calls = list(calls)
# Out:
# weave version 0.51.33 is available!  To upgrade, please run:
#  $ pip install weave --upgrade
# Logged in as Weights & Biases user: dominik-karasin.
# View Weave data at https://wandb.ai/highly-biased/final_reevaluation/weave

# %%
# Create user prompts lookup mappings  

dataset = weave.ref("set1_test:v0").get()

dataset_lookup_map = dict()
for row in dataset.rows:
    id = row.ref._extra[-1]
    user_prompt = row["user_prompt"]
    dataset_lookup_map[id] = user_prompt
# Out:
# Expected length of response rows (100) to match prefetched rows (720). Ignoring prefetched rows.

# %%
# Load data from weave

outputs = defaultdict(list)
counts = defaultdict(lambda: 0)
user_prompts = defaultdict(list)
ids = defaultdict(list)

for call in tqdm(calls):
    model_name = call.inputs["model"].model_name

    call_id = call.id

    payload = {
        "project_id":project_id,
        "filter":{"parent_ids":[call_id],"trace_roots_only":False},
        "limit":3000,
        "offset":0,
        "sort_by":[{"field":"started_at","direction":"desc"}],
        "include_feedback": False,
        "expand_columns":["inputs.example.user_prompt"]
    }

    response = requests.request("POST","https://trace.wandb.ai/calls/stream_query", 
                                headers={
                                    'Content-Type': 'application/json',
                                    'Accept': 'application/json'
                                    }, 
                                data=json.dumps(payload),
                                auth=HTTPBasicAuth("api", _wandb_api_key_via_netrc()))

    counts[model_name]+=call.inputs["self"].trials

    scores = []
    for child in tqdm(response.json(), leave=False):
        if 'Evaluation.summarize' in child["op_name"]:
            continue

        ids[model_name].append(child["id"])
        
        user_prompt_id = child["inputs"]["example"].rsplit("/", 1)[-1]
        user_prompts[model_name].append(dataset_lookup_map[user_prompt_id].split(", "))

        if child["output"] is not None:
            child_scorers = {}
            for k, v in child["output"]['scores'].items():
                if k in selected_metrics:
                    child_scorers[k] = v
            scores.append(child_scorers)
    
    outputs[model_name] += scores
# Out:
# 100%|██████████| 13/13 [04:20<00:00, 20.05s/it]

# %%
# Define model and metric replacement names for better readability and consistency

model_name_replacements = {
    'Llama3.2': "LLaMA 3.2 3B",
    'gemma2:27b': "Gemma 2 27B",
    'wizardlm2': "WizardLM-2",
    'Llama3.2:1B': "LLaMA 3.2 1B",
    'gemma2:2b': "Gemma 2 2B",
    'gemini-2.0-flash-001': "Gemini 2.0 Flash",
    'gemini-1.5-flash-8b-001': "Gemini 1.5 Flash-8B",
    'mistral': "Mistral",
    'gemini-1.5-flash-002': "Gemini 1.5 Flash",
    'solar': "Solar",
    'gpt-3.5-turbo-0125': "GPT-3.5 Turbo",
    'gpt-4o-mini-2024-07-18': "GPT-4o mini",
    'gpt-4o-2024-11-20': "GPT-4o"
}

metric_name_replacements = {
    "GoldenDescriptionROUGEScorer": "Golden Description ROUGE", 
    'GoldenDescriptionCosineTFIDFScorer': "Golden Description TF-IDF", 
    'GoldenDescriptionBLEUScorer': "Golden Description BLEU",
    "FleshReadingScorer": "FRE", 
    "KolmogorovComplexityNormalized": "KC CompressionRatio", 
    "KolmogorovComplexity": "KC", 
    "MissingTopicScorer": "MissingTopics",
    "StrLenScorer": "StringLength",
    'rouge1': "Golden Description ROUGE 1",
    'rouge2': "Golden Description ROUGE 2",
    'rougeL': "Golden Description ROUGE L",
    'rougeLsum': "Golden Description ROUGE sum",
    'stemmed': "Golden Description TF-IDF stemmed",
    'lemmatized': "Golden Description TF-IDF lemmatized",
    'bleu': "Golden Description BLEU",
    'brevity_penalty': "Golden Description BLEU brevity penalty",
    'length_ratio': "Golden Description BLEU length ratio",
    'translation_length': "Golden Description BLEU translation length",
    'reference_length': "Golden Description BLEU reference length",
    'precisions_1': "Golden Description BLEU precision 1",
    'precisions_2': "Golden Description BLEU precision 2",
    'precisions_3': "Golden Description BLEU precision 3",
    'precisions_4': "Golden Description BLEU precision 4",
}

# %%
# Processes loaded data, extract metric scores, positions, topics, and prompts 

results = {}

for model, data in tqdm(outputs.items()):

    results_per_model = defaultdict(list)

    prompts = user_prompts[model]
    ids_per_model = ids[model]

    if model in model_name_replacements:
        model = model_name_replacements[model]

    model = model.replace(":", "-")

    for metrics, prompt, id in zip(data, prompts, ids_per_model, strict=True):
        for metric in metrics.keys():

            if any("_" in key for key in metrics[metric]):
                for key in metrics[metric].keys():
                    pos, submetric = key.split("_", maxsplit=1)

                    if not pos.isdigit():
                        continue

                    res = {}
                    res["metric"] = metric_name_replacements[submetric] if submetric in metric_name_replacements else submetric
                    res["position"] = int(pos) + 1
                    res["score"] = metrics[metric][pos + "_" + submetric]
                    topic = next(key for key, val in metrics[metric].items() if val == res["score"] and not key[0].isdigit())
                    res["topic"] = topic.split("_")[0]
                    res["prompt"] = prompt
                    res["id"] = id
                    results_per_model[metric_name_replacements[submetric] if submetric in metric_name_replacements else submetric].append(res)

            
            else:
                for pos in range(0, 6):
                    if str(pos) not in list(metrics[metric].keys()) or metrics[metric][str(pos)] is None:
                        continue

                    res = {}
                    res["metric"] = metric_name_replacements[metric] if metric in metric_name_replacements else metric
                    res["position"] = pos + 1
                    res["score"] = metrics[metric][str(pos)]
                    res["topic"] = next(key for key, val in metrics[metric].items() if val == res["score"] and not key.isdigit())
                    res["prompt"] = prompt
                    res["id"] = id
                    results_per_model[metric_name_replacements[metric] if metric in metric_name_replacements else metric].append(res)

    results[model] = results_per_model
# Out:
# 100%|██████████| 13/13 [00:14<00:00,  1.13s/it]

# %%
# Gather max/min scores for each metric

axes_max_values = defaultdict(lambda: float("-inf"))
axes_min_values = defaultdict(lambda: float("inf"))

for model, model_data in tqdm(results.items()):
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)
        axes_max_values[metric] = max(axes_max_values[metric], df["score"].max())
        axes_min_values[metric] = min(axes_min_values[metric], df["score"].min())
# Out:
# 100%|██████████| 13/13 [00:02<00:00,  4.36it/s]

# %%
# Generate boxplots displaying the distributions per position

save_dir = r"plots/boxplots/per_position"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for model, model_data in tqdm(results.items()):
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)
        plt.figure(figsize=(10, 2.5))
        plt.clf()
        ax = sns.boxplot(data=df, x='position', y='score', 
                        color='white',width=0.3,dodge=True, whis=(1,99.8),flierprops={"marker": ".",'markersize':1.5})

        sns.stripplot(data=df, x='position', y='score', hue='topic', alpha=0.7, jitter=True, size=1)

        _ = plt.legend(title='', loc='lower center', bbox_to_anchor=(0.5, -0.4), ncol=6, 
                fontsize=8, frameon=False, markerscale=5)
        
        plt.title(f"{model}-{metric}")

        plt.savefig(f'{save_dir}/{model}_{metric}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
# Generate boxplots displaying the distributions per position, with fixed axis

save_dir = r"plots/boxplots/per_position_axis_fixed"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for model, model_data in tqdm(results.items()):
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)
        plt.figure(figsize=(10, 2.5))
        plt.clf()
        ax = sns.boxplot(data=df, x='position', y='score', 
                        color='white',width=0.3,dodge=True, whis=(1,99.8),flierprops={"marker": ".",'markersize':1.5})

        sns.stripplot(data=df, x='position', y='score', hue='topic', alpha=0.7, jitter=True, size=1)

        _ = plt.legend(title='', loc='lower center', bbox_to_anchor=(0.5, -0.4), ncol=6, 
                fontsize=8, frameon=False, markerscale=5)
        
        plt.title(f"{model}-{metric}")

        plt.ylim(axes_min_values[metric], axes_max_values[metric])

        plt.savefig(f'{save_dir}/{model}_{metric}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
# Generate boxplots displaying the distributions per topic

save_dir = r"plots/boxplots/per_topic"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for model, model_data in tqdm(results.items()):
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)
        plt.figure(figsize=(10, 2.5))
        plt.clf()
        ax = sns.boxplot(data=df, x='topic', y='score', 
                        color='white',width=0.3,dodge=True, whis=(1,99.8),flierprops={"marker": ".",'markersize':1.5})

        sns.stripplot(data=df, x='topic', y='score', hue='position', alpha=0.7, jitter=True, size=1, palette="pastel")

        _ = plt.legend(title='', bbox_to_anchor=(1.05, 1), loc='upper left', 
                fontsize=8, frameon=False, markerscale=5)
        
        plt.title(f"{model}-{metric}")

        plt.xticks(rotation = 90)

        plt.savefig(f'{save_dir}/{model}_{metric}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()
# Out:
# 100%|██████████| 13/13 [03:05<00:00, 14.28s/it]

# %%
# Generate boxplots displaying the distributions per topic, with a fixed axis

save_dir = r"plots/boxplots/per_topic_axis_fixed"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for model, model_data in tqdm(results.items()):
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)
        plt.figure(figsize=(10, 2.5))
        plt.clf()
        ax = sns.boxplot(data=df, x='topic', y='score', 
                        color='white',width=0.3,dodge=True, whis=(1,99.8),flierprops={"marker": ".",'markersize':1.5})

        sns.stripplot(data=df, x='topic', y='score', hue='position', alpha=0.7, jitter=True, size=1, palette="pastel")

        _ = plt.legend(title='', bbox_to_anchor=(1.05, 1), loc='upper left', 
                fontsize=8, frameon=False, markerscale=5)
        
        plt.title(f"{model}-{metric}")

        plt.xticks(rotation = 90)

        plt.ylim(axes_min_values[metric], axes_max_values[metric])

        plt.savefig(f'{save_dir}/{model}_{metric}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
# Join boxplot for metric StringLength and selected models

joined_boxplot_metric = "StringLength"
joined_boxplot_models = ["Gemini 1.5 Flash", "GPT-4o", "LLaMA 3.2 1B", "Solar", "Mistral", "Gemma 2 27B"]

plot_data = []
for model in joined_boxplot_models:
    if model in results:
        model_data = results[model]
        if joined_boxplot_metric in model_data:
            df = pd.DataFrame(model_data[joined_boxplot_metric])
            df["Model"] = model
            plot_data.append(df)


combined_df = pd.concat(plot_data, ignore_index=True)

position_values = sorted(combined_df["position"].unique())

combined_df["x_position"] = combined_df["position"].astype(str) + combined_df["Model"]

plt.figure(figsize=(2.5 * len(joined_boxplot_models), 4))

ax = sns.boxplot(data=combined_df, x='x_position', y='score', 
                 color='white', width=0.6, dodge=True, 
                 whis=(1, 99.8), flierprops={"marker": ".", 'markersize': 1.5})


sns.stripplot(data=combined_df, x='x_position', y='score', hue='topic', 
              alpha=0.7, jitter=0.2, size=1, dodge=False)

xtick_positions = []
xtick_labels = []
for i in range(0, len(joined_boxplot_models) * 6, 6):
    for pos in position_values:
        mid_x = pos + i - 1
        xtick_positions.append(mid_x)
        xtick_labels.append(pos)

plt.xticks(xtick_positions, xtick_labels)

for i in range(1, len(joined_boxplot_models) + 1):
    plt.axvline(x=len(position_values) * i - 0.5, color="gray", linestyle="--", linewidth=1)


    plt.text(1 / (len(joined_boxplot_models) * 2) + ((i-1) * 1 / (len(joined_boxplot_models) * 2) * 2), 0.95, joined_boxplot_models[i - 1], 
                horizontalalignment="center", fontsize=10, transform=plt.gca().transAxes)


plt.legend(title="", loc="lower center", bbox_to_anchor=(0.5, -0.18), ncol=6, fontsize=8, frameon=False,
            markerscale=5)

ax.grid(axis='y' )

ax.tick_params(axis='both', labelsize=8)

plt.ylim(0, 2750)

plt.xlabel("")
plt.ylabel("String Length", fontsize=10)

plt.show()

# %%
# Join boxplot for metric FRE and selected models

joined_boxplot_metric = "FRE"
joined_boxplot_models = ["LLaMA 3.2 3B", "GPT-3.5 Turbo", "Gemma 2 2B", "Solar", "Mistral", "Gemini 2.0 Flash"]

plot_data = []
for model in joined_boxplot_models:
    if model in results:
        model_data = results[model]
        if joined_boxplot_metric in model_data:
            df = pd.DataFrame(model_data[joined_boxplot_metric])
            df["Model"] = model
            plot_data.append(df)


combined_df = pd.concat(plot_data, ignore_index=True)

position_values = sorted(combined_df["position"].unique())

combined_df["x_position"] = combined_df["position"].astype(str) + combined_df["Model"]

plt.figure(figsize=(2.5 * len(joined_boxplot_models), 4))

ax = sns.boxplot(data=combined_df, x='x_position', y='score', 
                 color='white', width=0.6, dodge=True, 
                 whis=(1, 99.8), flierprops={"marker": ".", 'markersize': 1.5})


sns.stripplot(data=combined_df, x='x_position', y='score', hue='topic', 
              alpha=0.7, jitter=0.2, size=1, dodge=False)

xtick_positions = []
xtick_labels = []
for i in range(0, len(joined_boxplot_models) * 6, 6):
    for pos in position_values:
        mid_x = pos + i - 1
        xtick_positions.append(mid_x)
        xtick_labels.append(pos)

plt.xticks(xtick_positions, xtick_labels)

for i in range(1, len(joined_boxplot_models) + 1):
    plt.axvline(x=len(position_values) * i - 0.5, color="gray", linestyle="--", linewidth=1)


    plt.text(1 / (len(joined_boxplot_models) * 2) + ((i-1) * 1 / (len(joined_boxplot_models) * 2) * 2), 0.95, joined_boxplot_models[i - 1], 
                horizontalalignment="center", fontsize=10, transform=plt.gca().transAxes)


plt.legend(title="", loc="lower center", bbox_to_anchor=(0.5, -0.18), ncol=6, fontsize=8, frameon=False,
            markerscale=5)

ax.grid(axis='y' )

ax.tick_params(axis='both', labelsize=8)

plt.ylim(-50, 70)

plt.xlabel("")
plt.ylabel("FRE", fontsize=10)

plt.show()

# %%
# Create joined boxplots per position

save_dir = r"plots/joined_boxplots_per_position"

metrics = results["GPT-4o"].keys()

os.makedirs(save_dir, exist_ok=True)

joined_boxplot_models_A = ["LLaMA 3.2 3B", "GPT-3.5 Turbo", "Gemma 2 2B", "Solar", "Mistral", "Gemini 2.0 Flash"]
joined_boxplot_models_B = ["Gemini 1.5 Flash", "GPT-4o", "LLaMA 3.2 1B", "Solar", "Mistral", "Gemma 2 27B"]

for models in [joined_boxplot_models_A, joined_boxplot_models_B]:
    for metric in metrics:
        plot_data = []
        for model in models:
            model_data = results[model]
            df = pd.DataFrame(model_data[metric])
            df["Model"] = model
            plot_data.append(df)


        combined_df = pd.concat(plot_data, ignore_index=True)

        position_values = sorted(combined_df["position"].unique())

        combined_df["x_position"] = combined_df["position"].astype(str) + combined_df["Model"]

        plt.figure(figsize=(2.5 * len(models), 4))

        ax = sns.boxplot(data=combined_df, x='x_position', y='score', 
                        color='white', width=0.6, dodge=True, 
                        whis=(1, 99.8), flierprops={"marker": ".", 'markersize': 1.5})


        sns.stripplot(data=combined_df, x='x_position', y='score', hue='topic', 
                    alpha=0.7, jitter=0.2, size=1, dodge=False)

        xtick_positions = []
        xtick_labels = []
        for i in range(0, len(models) * 6, 6):
            for pos in position_values:
                mid_x = pos + i - 1
                xtick_positions.append(mid_x)
                xtick_labels.append(pos)

        plt.xticks(xtick_positions, xtick_labels)

        for i in range(1, len(models) + 1):
            plt.axvline(x=len(position_values) * i - 0.5, color="gray", linestyle="--", linewidth=1)


            plt.text(1 / (len(models) * 2) + ((i-1) * 1 / (len(models) * 2) * 2), 0.95, models[i - 1], 
                        horizontalalignment="center", fontsize=10, transform=plt.gca().transAxes)


        plt.legend(title="", loc="lower center", bbox_to_anchor=(0.5, -0.18), ncol=6, fontsize=8, frameon=False,
                    markerscale=5)

        ax.grid(axis='y' )

        ax.tick_params(axis='both', labelsize=8)


        plt.xlabel("")
        plt.ylabel(f"{metric}", fontsize=10)

        plt.savefig(f'{save_dir}/{metric}_{", ".join(models)}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
# Create joined boxplots per topic

save_dir = r"plots/boxpltos/joined_boxplots_per_topic"

os.makedirs(save_dir, exist_ok=True)

joined_boxplot_metrics = ["FRE", "KC CompressionRatio", "StringLength", "NamedEntityDensity", "Golden Description TF-IDF lemmatized", "Golden Description ROUGE sum", "Golden Description BLEU"]

joined_boxplot_models_A = ["LLaMA 3.2 3B", "GPT-3.5 Turbo", "Gemma 2 2B", "Solar", "Mistral", "Gemini 2.0 Flash"]
joined_boxplot_models_B = ["Gemini 1.5 Flash", "GPT-4o", "LLaMA 3.2 1B", "Solar", "Mistral", "Gemma 2 27B"]

for models in [joined_boxplot_models_A, joined_boxplot_models_B]:
    for metric in joined_boxplot_metrics:
        plot_data = []
        for model in models:
            model_data = results[model]
            df = pd.DataFrame(model_data[metric])
            df["Model"] = model
            plot_data.append(df)

        combined_df = pd.concat(plot_data, ignore_index=True)

        topic_values = sorted(combined_df["topic"].unique())

        combined_df["x_topic"] = combined_df["topic"].astype(str) + combined_df["Model"]

        plt.figure(figsize=(2.5 * len(models), 4))

        ax = sns.boxplot(data=combined_df, x='x_topic', y='score', 
                        color='white', width=0.6, dodge=True, 
                        whis=(1, 99.8), flierprops={"marker": ".", 'markersize': 1.5})


        sns.stripplot(data=combined_df, x='x_topic', y='score', hue='position', 
                    alpha=0.7, jitter=0.2, size=1, dodge=False, palette="pastel")

        xtick_positions = []
        xtick_labels = []
        for i in range(0, len(models) * 6, 6):
            for pos in range(len(topic_values)):
                mid_x = pos + i - 1
                xtick_positions.append(mid_x)
                xtick_labels.append(topic_values[pos - 1])

        plt.xticks(xtick_positions, xtick_labels)

        for i in range(1, len(models) + 1):
            plt.axvline(x=len(topic_values) * i - 0.5, color="gray", linestyle="--", linewidth=1)


            plt.text(1 / (len(models) * 2) + ((i-1) * 1 / (len(models) * 2) * 2), 0.95, models[i - 1], 
                        horizontalalignment="center", fontsize=10, transform=plt.gca().transAxes)


        plt.legend(title="", loc="center", bbox_to_anchor=(1.02, 0.5),  fontsize=8, frameon=False,
                    markerscale=5)

        ax.grid(axis='y' )

        ax.tick_params(axis='both', labelsize=8)


        plt.xlabel("")
        plt.ylabel(f"{metric}", fontsize=10)

        plt.xticks(rotation = 90)

        plt.savefig(f'{save_dir}/{metric}_{", ".join(models)}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
# Create swarmplots per position with fixed axis

save_dir = r"plots/swarmplots/per_position_axis_fixed"

total = 0
for metric_data in results.values():
    total += len(metric_data)

pbar = tqdm(total=total)

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

def start_subprocess(tmp_file_path):
    p = subprocess.Popen([sys.executable, 'helper/create_swarmplot.py', tmp_file_path, str(True)])
    p.wait()
    pbar.update(1)


with ThreadPool(processes=multiprocessing.cpu_count()) as pool:
    try:
        tmp_files = []
        for model, model_data in results.items():
            for metric, metric_data in model_data.items():
                if metric == "MissingTopics":
                    continue
                
                tmp = tempfile.NamedTemporaryFile(delete=False, mode="w+")
                json.dump({"model":model,
                            "metric":metric,
                            "metric_data":metric_data,
                            "axes_min":axes_min_values[metric].item(), 
                            "axes_max":axes_max_values[metric].item(),
                            "save_dir":save_dir}, tmp)
                tmp.flush()
                tmp_files.append(tmp.name)
                tmp.close()
                
        result = pool.map_async(start_subprocess, tmp_files)
        result.wait()
    finally: 
        pbar.close()
# Out:
#   5%|▌         | 15/286 [02:28<19:38,  4.35s/it]

# %%
# Create swarmplots per position

save_dir = r"plots/swarmplots/per_position"

total = 0
for metric_data in results.values():
    total += len(metric_data)

pbar = tqdm(total=total)

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

def start_subprocess(tmp_file_path):
    p = subprocess.Popen([sys.executable, 'helper/create_swarmplot.py', tmp_file_path, str(False)])
    p.wait()
    pbar.update(1)


with ThreadPool(processes=multiprocessing.cpu_count()) as pool:
    try:
        tmp_files = []
        for model, model_data in results.items():
            for metric, metric_data in model_data.items():
                if metric == "MissingTopics":
                    continue
                
                tmp = tempfile.NamedTemporaryFile(delete=False, mode="w+")
                json.dump({"model":model,
                            "metric":metric,
                            "metric_data":metric_data,
                            "axes_min":axes_min_values[metric].item(), 
                            "axes_max":axes_max_values[metric].item(),
                            "save_dir":save_dir}, tmp)
                tmp.flush()
                tmp_files.append(tmp.name)
                tmp.close()
                
        result = pool.map_async(start_subprocess, tmp_files)
        result.wait()
    finally: 
        pbar.close()

# %%
from scipy.stats import mannwhitneyu
from scipy.stats import ttest_ind
from scipy.stats import normaltest

def unpaired_analysis(f1,f2,alpha=0.01): # only one df is needed, then is for i for j

    def rank_biserial_correlation(U,n1,n2): # effect size
        r_mw = (2 * U) / (n1 * n2) - 1
        return r_mw


    if len(f1.dropna()) <= 1 or len(f2.dropna()) <= 1:
        return (1,1,1,'-')

    normal = False
    try:
            if normaltest(f1,nan_policy='omit').pvalue < alpha and normaltest(f2,nan_policy='omit').pvalue < alpha:
                normal = True
    except:
        pass
    if not normal:
        statsb = mannwhitneyu(f1,f2,alternative='two-sided',nan_policy='omit')
        statsg = mannwhitneyu(f1,f2,alternative='greater',nan_policy='omit')
        statsl = mannwhitneyu(f1,f2,alternative='less',nan_policy='omit')
        return (statsb.pvalue,statsg.pvalue,statsl.pvalue, rank_biserial_correlation(statsb.statistic,len(f1),len(f2)))
    else: # both normal
        statsb = ttest_ind(f1,f2,nan_policy='omit') 
        return statsb.statistic,statsb.pvalue,rank_biserial_correlation(statsb.statistic,len(f1),len(f2))

# %%
ll = []

for model, model_data in results.items():
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)

        alpha = 0.01

        metric_data = df[df["metric"] == metric]

        for i in range(0, len(metric_data["position"].unique())):
            for j in range(i + 1, len(metric_data["position"].unique())):

                scores_i = metric_data[metric_data["position"] == i]["score"]
                scores_j = metric_data[metric_data["position"] == j]["score"]

                stats = unpaired_analysis(scores_i, scores_j, alpha)

                dicti = {}
                dicti["metric"] = metric
                dicti["i"] = i
                dicti["j"] = j

                if len(stats) < 4:
                    dicti['effect_size'] = stats[2] if stats[1]/2 < alpha and stats[0] > 0 else '-'
                else: 
                    dicti['effect_size'] = stats[3] if stats[1] < alpha else '-'
    
                dicti["model"] = model

                ll.append(dicti)

        
pd.DataFrame(ll)
# Out:
#             metric  i  j effect_size                model
# 0              FRE  0  1           -         LLaMA 3.2 3B
# 1              FRE  0  2           -         LLaMA 3.2 3B
# 2              FRE  0  3           -         LLaMA 3.2 3B
# 3              FRE  0  4           -         LLaMA 3.2 3B
# 4              FRE  0  5           -         LLaMA 3.2 3B
# ...            ... .. ..         ...                  ...
# 4285  StringLength  2  4   -0.999986  Gemini 1.5 Flash-8B
# 4286  StringLength  2  5    0.567438  Gemini 1.5 Flash-8B
# 4287  StringLength  3  4   -0.999995  Gemini 1.5 Flash-8B
# 4288  StringLength  3  5    0.287165  Gemini 1.5 Flash-8B
# 4289  StringLength  4  5    0.090219  Gemini 1.5 Flash-8B
#
# [4290 rows x 5 columns]

# %%
# statistical significance of differences per ranking position -- dunn to apply a correction to mannwhitney
import scikit_posthocs as sp

dunn_test_results = defaultdict(list)

for model, model_data in results.items():
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)

        dunn_test = sp.posthoc_dunn(df, val_col='score', group_col='position', p_adjust='bonferroni')

        for posi in range(len(dunn_test.columns)):
            for posj in range(posi + 1, len(dunn_test.columns)):
                pvalue = dunn_test.iloc[posi, posj]

                
                dunn_test_results[model].append({
                    'metric': metric,        
                    'model': model,
                    'posi': posi,            
                    'posj': posj,            
                    'pvalue': pvalue
                })

dunn_test_df = pd.DataFrame([item for sublist in dunn_test_results.values() for item in sublist])

dunn_test_df
# Out:
# c:\Users\domin\AppData\Local\pypoetry\Cache\virtualenvs\highly-biased-R2dx9aw8-py3.12\Lib\site-packages\scikit_posthocs\_posthocs.py:361: RuntimeWarning: invalid value encountered in scalar divide
#   z_value = diff / np.sqrt((A - x_ties) * B)
# c:\Users\domin\AppData\Local\pypoetry\Cache\virtualenvs\highly-biased-R2dx9aw8-py3.12\Lib\site-packages\scikit_posthocs\_posthocs.py:361: RuntimeWarning: invalid value encountered in scalar divide
#   z_value = diff / np.sqrt((A - x_ties) * B)
# c:\Users\domin\AppData\Local\pypoetry\Cache\virtualenvs\highly-biased-R2dx9aw8-py3.12\Lib\site-packages\scikit_posthocs\_posthocs.py:361: RuntimeWarning: invalid value encountered in scalar divide
#   z_value = diff / np.sqrt((A - x_ties) * B)
# c:\Users\domin\AppData\Local\pypoetry\Cache\virtualenvs\highly-biased-R2dx9aw8-py3.12\Lib\site-packages\scikit_posthocs\_posthocs.py:361: RuntimeWarning: invalid value encountered in scalar divide
#   z_value = diff / np.sqrt((A - x_ties) * B)
# c:\Users\domin\AppData\Local\pypoetry\Cache\virtualenvs\highly-biased-R2dx9aw8-py3.12\Lib\site-packages\scikit_posthocs\_posthocs.py:361: RuntimeWarning: invalid value encountered in scalar divide
#   z_value = diff / np.sqrt((A - x_ties) * B)
#             metric                model  posi  posj         pvalue
# 0              FRE         LLaMA 3.2 3B     0     1   5.966809e-14
# 1              FRE         LLaMA 3.2 3B     0     2   6.071504e-48
# 2              FRE         LLaMA 3.2 3B     0     3   6.975165e-93
# 3              FRE         LLaMA 3.2 3B     0     4  1.919868e-148
# 4              FRE         LLaMA 3.2 3B     0     5  6.713267e-178
# ...            ...                  ...   ...   ...            ...
# 4285  StringLength  Gemini 1.5 Flash-8B     2     4   1.037744e-41
# 4286  StringLength  Gemini 1.5 Flash-8B     2     5   7.170567e-01
# 4287  StringLength  Gemini 1.5 Flash-8B     3     4   4.379689e-04
# 4288  StringLength  Gemini 1.5 Flash-8B     3     5   1.398661e-29
# 4289  StringLength  Gemini 1.5 Flash-8B     4     5   2.026256e-54
#
# [4290 rows x 5 columns]

# %%
# Friedman test
from scipy.stats import friedmanchisquare

for model, model_data in results.items():
    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)
        scores_per_pos = [df[df["position"] == idx]["score"].values for idx in range(1, 7)]

        # Need lists with same length 
        # Since our data has missing values => not equal length
        # Pad data with median to ensure same length

        padded_scores_per_pos = []
        max_len = max(map(len, scores_per_pos))

        for pos_list in scores_per_pos:
            pos_list = list(pos_list)
            median_value = np.median(pos_list)
            num_missing_values = (max_len - len(pos_list))
            if num_missing_values > 0:
                padded_list = pos_list + [median_value] * num_missing_values
                padded_scores_per_pos.append(padded_list)

            else:
                padded_scores_per_pos.append(pos_list)
   
        stat, p = friedmanchisquare(*padded_scores_per_pos)
        print(f"{model}, {metric}: p={p}, stat={stat}")
# Out:
# LLaMA 3.2 3B, FRE: p=5.389963847813714e-271, stat=1263.4126984126997
# LLaMA 3.2 3B, Golden Description BLEU: p=0.0, stat=2069.5634920634984
# LLaMA 3.2 3B, Golden Description BLEU brevity penalty: p=9.469900106191417e-122, stat=573.7527627417039
# LLaMA 3.2 3B, Golden Description BLEU length ratio: p=4.241843866544618e-122, stat=575.3674047407975
# LLaMA 3.2 3B, Golden Description BLEU translation length: p=4.244283908866855e-100, stat=473.46998963786103
# LLaMA 3.2 3B, Golden Description BLEU reference length: p=0.00029149905519224414, stat=23.333027535889116
# LLaMA 3.2 3B, Golden Description BLEU precision 1: p=0.0, stat=2078.9942718806283
# LLaMA 3.2 3B, Golden Description BLEU precision 2: p=0.0, stat=2466.1982776866503
# LLaMA 3.2 3B, Golden Description BLEU precision 3: p=0.0, stat=2301.519372461871
# LLaMA 3.2 3B, Golden Description BLEU precision 4: p=0.0, stat=2084.3150911448042
# LLaMA 3.2 3B, Golden Description TF-IDF stemmed: p=6.218876909296055e-174, stat=815.112962962965
# LLaMA 3.2 3B, Golden Description TF-IDF lemmatized: p=1.0423253920160401e-134, stat=633.7253968254008
# LLaMA 3.2 3B, Golden Description ROUGE 1: p=0.0, stat=2516.6320105820123
# LLaMA 3.2 3B, Golden Description ROUGE 2: p=0.0, stat=3605.7793650793683
# LLaMA 3.2 3B, Golden Description ROUGE L: p=0.0, stat=2800.6960317460325
# LLaMA 3.2 3B, Golden Description ROUGE sum: p=0.0, stat=1666.6050264550286
# LLaMA 3.2 3B, KC: p=6.0371603722634e-24, stat=118.65850751013274
# LLaMA 3.2 3B, KC CompressionRatio: p=1.7894557995756482e-126, stat=595.6176750707722
# LLaMA 3.2 3B, MissingTopics: p=0.0, stat=2523.6095949439914
# LLaMA 3.2 3B, NamedEntityDensity: p=9.38902436136075e-06, stat=30.99489255848985
# LLaMA 3.2 3B, StringLength: p=4.686183964188388e-44, stat=213.00144261947926
# LLaMA 3.2 3B, TopicConsistency: p=0.00362260432525862, stat=17.51322751322732
# WizardLM-2, KC CompressionRatio: p=3.1536917528205327e-119, stat=562.0748677248703
# WizardLM-2, FRE: p=0.10971275629696642, stat=8.983782854271707
# WizardLM-2, Golden Description TF-IDF stemmed: p=4.019642986003245e-15, stat=76.74550264550635
# WizardLM-2, Golden Description TF-IDF lemmatized: p=4.823764656345744e-11, stat=57.09947089947673
# WizardLM-2, TopicConsistency: p=1.251488288856435e-07, stat=40.38042180659977
# WizardLM-2, MissingTopics: p=0.0001467242974141543, stat=24.88372093093639
# WizardLM-2, Golden Description ROUGE 1: p=2.282623720828688e-231, stat=1080.4558201058244
# WizardLM-2, Golden Description ROUGE 2: p=1.5831552858243328e-58, stat=280.46290294845136
# WizardLM-2, Golden Description ROUGE L: p=1.6022537031808887e-75, stat=359.46666666666715
# WizardLM-2, Golden Description ROUGE sum: p=5.508645441930721e-109, stat=514.6441798941814
# WizardLM-2, StringLength: p=0.0, stat=1626.51436929961
# WizardLM-2, Golden Description BLEU: p=1.0908268454752876e-186, stat=874.0653011505877
# WizardLM-2, Golden Description BLEU brevity penalty: p=4.0516408768053817e-261, stat=1217.821749427757
# WizardLM-2, Golden Description BLEU length ratio: p=3.569352884477845e-257, stat=1199.609415313781
# WizardLM-2, Golden Description BLEU translation length: p=2.113202827917874e-264, stat=1232.9761351103577
# WizardLM-2, Golden Description BLEU reference length: p=0.9901620686328723, stat=0.5503848219104049
# WizardLM-2, Golden Description BLEU precision 1: p=3.389830449262959e-22, stat=110.38952534660021
# WizardLM-2, Golden Description BLEU precision 2: p=7.979117056008454e-11, stat=56.03861570822149
# WizardLM-2, Golden Description BLEU precision 3: p=2.6491226694193343e-07, stat=38.76411036856239
# WizardLM-2, Golden Description BLEU precision 4: p=3.931626460644541e-07, stat=37.91109404380784
# WizardLM-2, KC: p=0.0, stat=1498.91088912148
# WizardLM-2, NamedEntityDensity: p=0.12601927514256153, stat=8.602267915739906
# LLaMA 3.2 1B, FRE: p=8.525615328700734e-96, stat=453.52575135707593
# LLaMA 3.2 1B, Golden Description BLEU: p=2.877132235443197e-292, stat=1361.6009532636017
# LLaMA 3.2 1B, Golden Description BLEU brevity penalty: p=1.879241704338329e-145, stat=683.4292753354428
# LLaMA 3.2 1B, Golden Description BLEU length ratio: p=5.028129432969141e-151, stat=709.2026729893
# LLaMA 3.2 1B, Golden Description BLEU translation length: p=5.297050465872425e-144, stat=676.7220407404444
# LLaMA 3.2 1B, Golden Description BLEU reference length: p=8.502128163402843e-19, stat=94.27060379021628
# LLaMA 3.2 1B, Golden Description BLEU precision 1: p=3.0043814479450684e-83, stat=395.3345294211125
# LLaMA 3.2 1B, Golden Description BLEU precision 2: p=9.723628258372575e-112, stat=527.3963588215852
# LLaMA 3.2 1B, Golden Description BLEU precision 3: p=6.856390752974297e-110, stat=518.8358667443425
# LLaMA 3.2 1B, Golden Description BLEU precision 4: p=4.1583452555278445e-112, stat=529.1049084384866
# LLaMA 3.2 1B, Golden Description TF-IDF stemmed: p=2.0117770118431866e-64, stat=307.8927578445655
# LLaMA 3.2 1B, Golden Description TF-IDF lemmatized: p=1.1899263710433173e-46, stat=225.1177015755311
# LLaMA 3.2 1B, Golden Description ROUGE 1: p=0.0, stat=1658.221898583346
# LLaMA 3.2 1B, Golden Description ROUGE 2: p=0.0, stat=1609.6626506024113
# LLaMA 3.2 1B, Golden Description ROUGE L: p=0.0, stat=1501.2932609559139
# LLaMA 3.2 1B, Golden Description ROUGE sum: p=2.0213841049085943e-205, stat=960.6124718654828
# LLaMA 3.2 1B, KC: p=1.551967186614385e-97, stat=461.59067412453555
# LLaMA 3.2 1B, KC CompressionRatio: p=6.0219623046774e-146, stat=685.7153448960671
# LLaMA 3.2 1B, MissingTopics: p=0.0, stat=6989.870882589243
# LLaMA 3.2 1B, NamedEntityDensity: p=2.219737822043322e-27, stat=134.8528886005188
# LLaMA 3.2 1B, StringLength: p=4.2254381767260904e-129, stat=607.7751798322896
# LLaMA 3.2 1B, TopicConsistency: p=0.12506487494641208, stat=8.623328478752228
# Gemini 2.0 Flash, Golden Description ROUGE 1: p=4.2099754791090154e-91, stat=431.7642857142855
# Gemini 2.0 Flash, Golden Description ROUGE 2: p=3.877820072104931e-18, stat=91.13624338624504
# Gemini 2.0 Flash, Golden Description ROUGE L: p=3.87430095418818e-39, stat=190.01693121693097
# Gemini 2.0 Flash, Golden Description ROUGE sum: p=1.9590576362994003e-10, stat=54.142592592594156
# Gemini 2.0 Flash, NamedEntityDensity: p=0.008117311054041253, stat=15.590071972910334
# Gemini 2.0 Flash, TopicConsistency: p=5.402719695023805e-36, stat=175.29708994709654
# Gemini 2.0 Flash, KC CompressionRatio: p=1.2177459477033745e-91, stat=434.26242410614344
# Gemini 2.0 Flash, Golden Description TF-IDF stemmed: p=0.0403181642325246, stat=11.624074074075907
# Gemini 2.0 Flash, Golden Description TF-IDF lemmatized: p=0.024359891738558515, stat=12.897354497355991
# Gemini 2.0 Flash, MissingTopics: p=nan, stat=nan
# c:\Users\domin\AppData\Local\pypoetry\Cache\virtualenvs\highly-biased-R2dx9aw8-py3.12\Lib\site-packages\scipy\stats\_stats_py.py:8711: RuntimeWarning: invalid value encountered in scalar divide
#   statistic = (12.0 / (k*n*(k+1)) * ssbn - 3*n*(k+1)) / c
# Gemini 2.0 Flash, KC: p=0.0, stat=2350.2324718848154
# Gemini 2.0 Flash, FRE: p=1.0610158547207742e-59, stat=285.925925925927
# Gemini 2.0 Flash, Golden Description BLEU: p=6.424727503639677e-95, stat=449.45952380952804
# Gemini 2.0 Flash, Golden Description BLEU brevity penalty: p=1.2797112471648544e-120, stat=568.5179894179892
# Gemini 2.0 Flash, Golden Description BLEU length ratio: p=2.0896721000339222e-123, stat=581.4198412698461
# Gemini 2.0 Flash, Golden Description BLEU translation length: p=4.092150222429189e-266, stat=1240.8838920469645
# Gemini 2.0 Flash, Golden Description BLEU reference length: p=1.0, stat=0.0
# Gemini 2.0 Flash, Golden Description BLEU precision 1: p=1.386316275855408e-69, stat=331.8870707444885
# Gemini 2.0 Flash, Golden Description BLEU precision 2: p=7.661706131815024e-27, stat=132.31913964840328
# Gemini 2.0 Flash, Golden Description BLEU precision 3: p=9.78831212525694e-10, stat=50.73756613756996
# Gemini 2.0 Flash, Golden Description BLEU precision 4: p=0.0023440015246345464, stat=18.536496640034258
# Gemini 2.0 Flash, StringLength: p=0.0, stat=1567.9189389527248
# Mistral, FRE: p=6.139870467986707e-08, stat=41.910972947951265
# Mistral, Golden Description BLEU: p=1.0017928308993708e-75, stat=360.41375661375787
# Mistral, Golden Description BLEU brevity penalty: p=1.302383782734243e-170, stat=799.7621725324199
# Mistral, Golden Description BLEU length ratio: p=2.000195619784081e-163, stat=766.5409295987128
# Mistral, Golden Description BLEU translation length: p=1.9925895449099267e-205, stat=960.6412563825692
# Mistral, Golden Description BLEU reference length: p=0.9996060613137837, stat=0.1434537002007109
# Mistral, Golden Description BLEU precision 1: p=2.755909880131418e-81, stat=386.22727513298173
# Mistral, Golden Description BLEU precision 2: p=4.809364344820656e-53, stat=254.93054544974083
# Mistral, Golden Description BLEU precision 3: p=1.615362109798574e-44, stat=215.16155067478564
# Mistral, Golden Description BLEU precision 4: p=2.3204358725191297e-45, stat=219.09619583196104
# Mistral, Golden Description TF-IDF stemmed: p=2.407524496253841e-22, stat=111.09259259259852
# Mistral, Golden Description TF-IDF lemmatized: p=9.698188376375164e-21, stat=103.49206349206361
# Mistral, Golden Description ROUGE 1: p=1.745609707083945e-110, stat=521.5878306878367
# Mistral, Golden Description ROUGE 2: p=1.962961855170743e-15, stat=78.2351851851854
# Mistral, Golden Description ROUGE L: p=1.4917587110758904e-43, stat=210.65264550264692
# Mistral, Golden Description ROUGE sum: p=1.6047286372970385e-53, stat=257.15158730158873
# Mistral, KC: p=2.1239886049996304e-276, stat=1288.3596030356105
# Mistral, KC CompressionRatio: p=2.6685339149130936e-131, stat=617.9543740822623
# Mistral, MissingTopics: p=3.118634183021374e-07, stat=38.41176470721099
# Mistral, NamedEntityDensity: p=0.028706152151073427, stat=12.485669274662282
# Mistral, StringLength: p=7.061631704563282e-308, stat=1433.6423621692584
# Mistral, TopicConsistency: p=1.367648070930397e-25, stat=126.42037037037517
# Gemini 1.5 Flash, Golden Description ROUGE 1: p=0.0, stat=3486.493915343919
# Gemini 1.5 Flash, Golden Description ROUGE 2: p=9.893616764355834e-173, stat=809.5587301587366
# Gemini 1.5 Flash, Golden Description ROUGE L: p=2.308416436185215e-162, stat=761.6298941798959
# Gemini 1.5 Flash, Golden Description ROUGE sum: p=8.3073572347708355e-165, stat=772.9283068783116
# Gemini 1.5 Flash, NamedEntityDensity: p=0.06363678859704583, stat=10.4420229447061
# Gemini 1.5 Flash, TopicConsistency: p=5.661250322194528e-117, stat=551.6383597883614
# Gemini 1.5 Flash, KC CompressionRatio: p=1.743522194672743e-79, stat=377.867309549322
# Gemini 1.5 Flash, Golden Description TF-IDF stemmed: p=1.1402030767349127e-42, stat=206.52619047619373
# Gemini 1.5 Flash, Golden Description TF-IDF lemmatized: p=5.87300684723823e-08, stat=42.006349206349114
# Gemini 1.5 Flash, MissingTopics: p=nan, stat=nan
# Gemini 1.5 Flash, KC: p=0.0, stat=7007.84265270969
# Gemini 1.5 Flash, FRE: p=0.3446504908633264, stat=5.62296621604386
# Gemini 1.5 Flash, Golden Description BLEU: p=0.0, stat=3005.095502645505
# Gemini 1.5 Flash, Golden Description BLEU brevity penalty: p=0.0, stat=5368.357671957674
# Gemini 1.5 Flash, Golden Description BLEU length ratio: p=0.0, stat=5386.819576719579
# Gemini 1.5 Flash, Golden Description BLEU translation length: p=0.0, stat=5474.922824323966
# Gemini 1.5 Flash, Golden Description BLEU reference length: p=1.0, stat=0.0
# Gemini 1.5 Flash, Golden Description BLEU precision 1: p=2.0052012460209332e-306, stat=1426.9358380738229
# Gemini 1.5 Flash, Golden Description BLEU precision 2: p=1.842148030562754e-13, stat=68.77568028786071
# Gemini 1.5 Flash, Golden Description BLEU precision 3: p=0.0383186114992585, stat=11.753994920368838
# Gemini 1.5 Flash, Golden Description BLEU precision 4: p=1.8372512351542296e-15, stat=78.37268830860242
# Gemini 1.5 Flash, StringLength: p=0.0, stat=6646.566475595389
# Solar, FRE: p=2.206563099394566e-09, stat=49.01218399015746
# Solar, Golden Description BLEU: p=6.158470395507631e-67, stat=319.5817223664054
# Solar, Golden Description BLEU brevity penalty: p=0.0, stat=1600.6105820105877
# Solar, Golden Description BLEU length ratio: p=0.0, stat=1652.0089947089946
# Solar, Golden Description BLEU translation length: p=0.0, stat=2530.9697183849853
# Solar, Golden Description BLEU reference length: p=1.0, stat=0.0
# Solar, Golden Description BLEU precision 1: p=2.6372895735703387e-295, stat=1375.6212363848147
# Solar, Golden Description BLEU precision 2: p=4.425653613272168e-213, stat=995.9948537485661
# Solar, Golden Description BLEU precision 3: p=6.33634294951118e-156, stat=731.8600989653685
# Solar, Golden Description BLEU precision 4: p=4.593732529450188e-115, stat=542.7976316626057
# Solar, Golden Description TF-IDF stemmed: p=7.322187355123047e-07, stat=36.5645502645566
# Solar, Golden Description TF-IDF lemmatized: p=9.168321344706273e-07, stat=36.076719576725736
# Solar, Golden Description ROUGE 1: p=1.2816455693557762e-128, stat=605.5449735449802
# Solar, Golden Description ROUGE 2: p=8.966401035024706e-19, stat=94.1608465608515
# Solar, Golden Description ROUGE L: p=2.079412054234183e-12, stat=63.705291005295294
# Solar, Golden Description ROUGE sum: p=3.6033816112517146e-12, stat=62.552645502648375
# Solar, KC: p=0.0, stat=3968.155286343618
# Solar, KC CompressionRatio: p=6.781593101226643e-147, stat=690.101992221606
# Solar, MissingTopics: p=nan, stat=nan
# Solar, NamedEntityDensity: p=6.063174805613253e-05, stat=26.863871642463312
# Solar, StringLength: p=0.0, stat=4074.512408410959
# Solar, TopicConsistency: p=0.0048647318919395315, stat=16.81481481481751
# GPT-3.5 Turbo, FRE: p=7.269478408281368e-63, stat=300.6472821557589
# GPT-3.5 Turbo, Golden Description BLEU: p=5.142744772304884e-108, stat=510.15026455026964
# GPT-3.5 Turbo, Golden Description BLEU brevity penalty: p=2.3300807266387198e-166, stat=780.1036043188316
# GPT-3.5 Turbo, Golden Description BLEU length ratio: p=1.9800046599389576e-170, stat=798.9212183762071
# GPT-3.5 Turbo, Golden Description BLEU translation length: p=4.290147524150621e-173, stat=811.2360614629516
# GPT-3.5 Turbo, Golden Description BLEU reference length: p=0.9909462180068627, stat=0.5309482478083013
# GPT-3.5 Turbo, Golden Description BLEU precision 1: p=2.4201022402779997e-13, stat=68.20567610479145
# GPT-3.5 Turbo, Golden Description BLEU precision 2: p=4.9771773651562525e-14, stat=71.50652219929732
# GPT-3.5 Turbo, Golden Description BLEU precision 3: p=1.4743717787571269e-05, stat=30.000727686492663
# GPT-3.5 Turbo, Golden Description BLEU precision 4: p=0.006784450753746225, stat=16.02097254383495
# GPT-3.5 Turbo, Golden Description TF-IDF stemmed: p=8.780779675392861e-38, stat=183.6746031746079
# GPT-3.5 Turbo, Golden Description TF-IDF lemmatized: p=1.6199828597844276e-47, stat=229.15873015873512
# GPT-3.5 Turbo, Golden Description ROUGE 1: p=9.03682157903568e-91, stat=430.2259259259299
# GPT-3.5 Turbo, Golden Description ROUGE 2: p=2.9390464727754453e-13, stat=67.799735449742
# GPT-3.5 Turbo, Golden Description ROUGE L: p=6.3163316442704504e-58, stat=277.66560846561333
# GPT-3.5 Turbo, Golden Description ROUGE sum: p=6.75013770011918e-47, stat=226.26666666667006
# GPT-3.5 Turbo, KC: p=8.30492034317157e-276, stat=1285.6261363485598
# GPT-3.5 Turbo, KC CompressionRatio: p=1.4029265137651901e-87, stat=415.4262186652617
# GPT-3.5 Turbo, MissingTopics: p=0.2278201955155299, stat=6.904761912301023
# GPT-3.5 Turbo, NamedEntityDensity: p=0.013265723395327505, stat=14.398686840608969
# GPT-3.5 Turbo, StringLength: p=3.902952156138885e-273, stat=1273.2919801822866
# GPT-3.5 Turbo, TopicConsistency: p=2.5645882011523463e-124, stat=585.6370370370423
# GPT-4o mini, Golden Description ROUGE 1: p=1.061971257308083e-111, stat=527.2190476190517
# GPT-4o mini, Golden Description ROUGE 2: p=2.3502680086997668e-08, stat=43.96878306878352
# GPT-4o mini, Golden Description ROUGE L: p=3.666518106812623e-30, stat=147.93862433862523
# GPT-4o mini, Golden Description ROUGE sum: p=8.58933101884173e-52, stat=249.09656084656308
# GPT-4o mini, NamedEntityDensity: p=5.53038621079703e-15, stat=76.08199671801684
# GPT-4o mini, TopicConsistency: p=2.3446302242395727e-25, stat=125.31640211640479
# GPT-4o mini, KC CompressionRatio: p=8.452794865474371e-89, stat=421.08508161592016
# GPT-4o mini, Golden Description TF-IDF stemmed: p=4.505455974905584e-46, stat=222.4190476190488
# GPT-4o mini, Golden Description TF-IDF lemmatized: p=1.280633968390117e-29, stat=145.38571428571595
# GPT-4o mini, MissingTopics: p=nan, stat=nan
# GPT-4o mini, KC: p=1.3860254046210594e-220, stat=1030.655422517471
# GPT-4o mini, FRE: p=2.3959032619439433e-24, stat=120.55360071961593
# GPT-4o mini, Golden Description BLEU: p=1.8007425346737733e-72, stat=345.29761904762563
# GPT-4o mini, Golden Description BLEU brevity penalty: p=2.587343626259214e-91, stat=432.7447089947091
# GPT-4o mini, Golden Description BLEU length ratio: p=2.706487536382985e-97, stat=460.4711640211681
# GPT-4o mini, Golden Description BLEU translation length: p=3.1500346181982022e-170, stat=797.9890964280497
# GPT-4o mini, Golden Description BLEU reference length: p=1.0, stat=0.0
# GPT-4o mini, Golden Description BLEU precision 1: p=4.1589791375909477e-08, stat=42.74653384135517
# GPT-4o mini, Golden Description BLEU precision 2: p=5.756524007170566e-05, stat=26.97965312413308
# GPT-4o mini, Golden Description BLEU precision 3: p=4.911110335525761e-06, stat=32.417385437616424
# GPT-4o mini, Golden Description BLEU precision 4: p=4.709736070655071e-09, stat=47.399494662203885
# GPT-4o mini, StringLength: p=9.099731141291143e-236, stat=1100.771615159426
# GPT-4o, FRE: p=0.0004595539842495495, stat=22.297812111432652
# GPT-4o, Golden Description BLEU: p=8.561923065798174e-96, stat=453.51719576719915
# GPT-4o, Golden Description BLEU brevity penalty: p=1.696652774294543e-109, stat=517.0132275132273
# GPT-4o, Golden Description BLEU length ratio: p=5.057997200889361e-109, stat=514.8158730158757
# GPT-4o, Golden Description BLEU translation length: p=2.8325709986742075e-189, stat=886.0129510943309
# GPT-4o, Golden Description BLEU reference length: p=1.0, stat=0.0
# GPT-4o, Golden Description BLEU precision 1: p=3.357452025438213e-41, stat=199.6606379741514
# GPT-4o, Golden Description BLEU precision 2: p=4.685270974412951e-18, stat=90.74532682462765
# GPT-4o, Golden Description BLEU precision 3: p=3.9107912466205606e-14, stat=72.00920732352627
# GPT-4o, Golden Description BLEU precision 4: p=5.5910079330433295e-21, stat=104.62568295167976
# GPT-4o, Golden Description TF-IDF stemmed: p=0.008551305214949323, stat=15.46455026455078
# GPT-4o, Golden Description TF-IDF lemmatized: p=0.006536791912840614, stat=16.110052910058585
# GPT-4o, Golden Description ROUGE 1: p=6.171151205069537e-82, stat=389.24338624339
# GPT-4o, Golden Description ROUGE 2: p=5.133563634700801e-19, stat=95.31190476191114
# GPT-4o, Golden Description ROUGE L: p=6.918231516355981e-24, stat=118.37910052910593
# GPT-4o, Golden Description ROUGE sum: p=2.185222228949966e-74, stat=354.1968253968298
# GPT-4o, KC: p=4.450357482741207e-309, stat=1439.1824704259718
# GPT-4o, KC CompressionRatio: p=5.122720836508295e-56, stat=268.77728246779077
# GPT-4o, MissingTopics: p=nan, stat=nan
# GPT-4o, NamedEntityDensity: p=0.0057992375684933544, stat=16.396265862147217
# GPT-4o, StringLength: p=0.0, stat=1748.452421939145
# GPT-4o, TopicConsistency: p=3.7522482179471225e-15, stat=76.8886243386296
# Gemma 2 2B, Golden Description ROUGE 1: p=7.191538076802276e-52, stat=249.4560846560853
# Gemma 2 2B, Golden Description ROUGE 2: p=2.414576126503179e-47, stat=228.35000000000582
# Gemma 2 2B, Golden Description ROUGE L: p=6.972125358861267e-55, stat=263.49656084656453
# Gemma 2 2B, Golden Description ROUGE sum: p=2.5949562209500693e-39, stat=190.8312169312194
# Gemma 2 2B, NamedEntityDensity: p=1.6138783090707782e-16, stat=83.41977631718431
# Gemma 2 2B, TopicConsistency: p=9.581650638092932e-202, stat=943.6314325451967
# Gemma 2 2B, KC CompressionRatio: p=2.4914102866177547e-05, stat=28.840967494101
# Gemma 2 2B, Golden Description TF-IDF stemmed: p=2.7046994939059463e-41, stat=200.09954301609105
# Gemma 2 2B, Golden Description TF-IDF lemmatized: p=3.622594498128162e-33, stat=162.04801642492384
# Gemma 2 2B, MissingTopics: p=6.402258561064143e-06, stat=31.836065573758052
# Gemma 2 2B, KC: p=3.0851033477444073e-107, stat=506.5459103812327
# Gemma 2 2B, FRE: p=1.2526751789450641e-49, stat=239.00851734597384
# Gemma 2 2B, Golden Description BLEU: p=3.8869306211910585e-103, stat=487.5489481289013
# Gemma 2 2B, Golden Description BLEU brevity penalty: p=1.3225443935844107e-100, stat=475.816791667771
# Gemma 2 2B, Golden Description BLEU length ratio: p=1.802065906744478e-100, stat=475.19412715659837
# Gemma 2 2B, Golden Description BLEU translation length: p=5.764006191932385e-102, stat=482.12231172076116
# Gemma 2 2B, Golden Description BLEU reference length: p=0.10942603372456405, stat=8.990941081697933
# Gemma 2 2B, Golden Description BLEU precision 1: p=4.396301133863648e-133, stat=626.2059119696802
# Gemma 2 2B, Golden Description BLEU precision 2: p=1.5987099840280774e-70, stat=336.2460586629916
# Gemma 2 2B, Golden Description BLEU precision 3: p=1.626632158556465e-45, stat=219.816439009524
# Gemma 2 2B, Golden Description BLEU precision 4: p=3.836471976465725e-29, stat=143.1453708860408
# Gemma 2 2B, StringLength: p=5.263032360873643e-89, stat=422.03942048963455
# Gemma 2 27B, Golden Description ROUGE 1: p=2.0960718582277956e-161, stat=757.2002645502653
# Gemma 2 27B, Golden Description ROUGE 2: p=2.024970161266468e-78, stat=372.9235449735497
# Gemma 2 27B, Golden Description ROUGE L: p=4.537298921231393e-77, stat=366.6542328042342
# Gemma 2 27B, Golden Description ROUGE sum: p=1.737017803261102e-108, stat=512.3338624338649
# Gemma 2 27B, NamedEntityDensity: p=0.6842028320720314, stat=3.102396485330724
# Gemma 2 27B, TopicConsistency: p=6.532722631530856e-06, stat=31.79179894180561
# Gemma 2 27B, KC CompressionRatio: p=1.539611482784501e-35, stat=173.1663954918859
# Gemma 2 27B, Golden Description TF-IDF stemmed: p=5.1054403332718004e-11, stat=56.97989417989447
# Gemma 2 27B, Golden Description TF-IDF lemmatized: p=3.6651676423454625e-11, stat=57.678042328043375
# Gemma 2 27B, MissingTopics: p=1.0967326049657928e-48, stat=234.61403508808573
# Gemma 2 27B, KC: p=8.018440788908612e-238, stat=1110.2606609949435
# Gemma 2 27B, FRE: p=6.3114390181237385e-09, stat=46.77595375416927
# Gemma 2 27B, Golden Description BLEU: p=5.397414767522153e-182, stat=852.3714285714304
# Gemma 2 27B, Golden Description BLEU brevity penalty: p=1.0765548335709842e-214, stat=1003.4496539494752
# Gemma 2 27B, Golden Description BLEU length ratio: p=1.2888086922067797e-215, stat=1007.7075972315992
# Gemma 2 27B, Golden Description BLEU translation length: p=3.3789696763006233e-202, stat=945.722617543399
# Gemma 2 27B, Golden Description BLEU reference length: p=0.8116588670593855, stat=2.263182713379666
# Gemma 2 27B, Golden Description BLEU precision 1: p=4.440824555782719e-31, stat=152.24555136601592
# Gemma 2 27B, Golden Description BLEU precision 2: p=0.008784988459223436, stat=15.39950516664211
# Gemma 2 27B, Golden Description BLEU precision 3: p=1.0252398347390231e-06, stat=35.83404992790569
# Gemma 2 27B, Golden Description BLEU precision 4: p=2.2246829822239353e-15, stat=77.97512898531967
# Gemma 2 27B, StringLength: p=3.1448520008128434e-213, stat=996.6802155463465
# Gemini 1.5 Flash-8B, Golden Description ROUGE 1: p=0.0, stat=3436.2850050055495
# Gemini 1.5 Flash-8B, Golden Description ROUGE 2: p=0.0, stat=1850.3795730057368
# Gemini 1.5 Flash-8B, Golden Description ROUGE L: p=0.0, stat=2413.5977028599245
# Gemini 1.5 Flash-8B, Golden Description ROUGE sum: p=0.0, stat=2463.1081062799294
# Gemini 1.5 Flash-8B, NamedEntityDensity: p=1.5152736285664477e-33, stat=163.82349731248954
# Gemini 1.5 Flash-8B, TopicConsistency: p=4.970435844579239e-46, stat=222.21994815118524
# Gemini 1.5 Flash-8B, KC CompressionRatio: p=6.451467886195025e-159, stat=745.6956302337618
# Gemini 1.5 Flash-8B, Golden Description TF-IDF stemmed: p=5.911314976612484e-63, stat=301.0650528469123
# Gemini 1.5 Flash-8B, Golden Description TF-IDF lemmatized: p=1.4582208832545536e-26, stat=131.00245482441096
# Gemini 1.5 Flash-8B, MissingTopics: p=0.7650450970731519, stat=2.57575757780376
# Gemini 1.5 Flash-8B, KC: p=0.0, stat=3712.7454125935233
# Gemini 1.5 Flash-8B, FRE: p=4.570715196051947e-14, stat=71.68414664084102
# Gemini 1.5 Flash-8B, Golden Description BLEU: p=0.0, stat=3511.6350258445536
# Gemini 1.5 Flash-8B, Golden Description BLEU brevity penalty: p=0.0, stat=3773.045195350865
# Gemini 1.5 Flash-8B, Golden Description BLEU length ratio: p=0.0, stat=3780.159813925567
# Gemini 1.5 Flash-8B, Golden Description BLEU translation length: p=0.0, stat=3448.510580055292
# Gemini 1.5 Flash-8B, Golden Description BLEU reference length: p=0.986467310446352, stat=0.632491693422492
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 1: p=2.2409790990799964e-32, stat=158.33472004364515
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 2: p=9.7435837758771e-26, stat=127.11468165202392
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 3: p=6.395267685111231e-15, stat=75.77976458392811
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 4: p=8.636646698336719e-11, stat=55.87160217678956
# Gemini 1.5 Flash-8B, StringLength: p=0.0, stat=3645.9465433261003

# %%
# Kruskal Wallis test
from scipy.stats import kruskal

for model, model_data in results.items():
    for metric, metric_data in model_data.items():
        # Exclude Missing topics since it is sometime just the same value (not allowed in this test)
        if metric == "MissingTopics":
            continue
        df = pd.DataFrame(metric_data)
        scores_per_pos = [df[df["position"] == idx]["score"].values for idx in range(1, 7)]
        stat, p = kruskal(*scores_per_pos)
        print(f"{model}, {metric}: p={p}, stat={stat}")
# Out:
# LLaMA 3.2 3B, FRE: p=1.9372937667990565e-263, stat=1228.5339799978385
# LLaMA 3.2 3B, Golden Description BLEU: p=0.0, stat=2046.2095831574863
# LLaMA 3.2 3B, Golden Description BLEU brevity penalty: p=8.471068367660103e-111, stat=523.0422169764244
# LLaMA 3.2 3B, Golden Description BLEU length ratio: p=1.8886231825478844e-110, stat=521.4294346119184
# LLaMA 3.2 3B, Golden Description BLEU translation length: p=2.793207845880857e-97, stat=460.40767410712795
# LLaMA 3.2 3B, Golden Description BLEU reference length: p=0.9985458080873304, stat=0.2454000302750965
# LLaMA 3.2 3B, Golden Description BLEU precision 1: p=0.0, stat=1855.6783649094236
# LLaMA 3.2 3B, Golden Description BLEU precision 2: p=0.0, stat=2286.461185650448
# LLaMA 3.2 3B, Golden Description BLEU precision 3: p=0.0, stat=2159.3261714577015
# LLaMA 3.2 3B, Golden Description BLEU precision 4: p=0.0, stat=1972.805578795106
# LLaMA 3.2 3B, Golden Description TF-IDF stemmed: p=1.2210392362971488e-150, stat=707.420667941522
# LLaMA 3.2 3B, Golden Description TF-IDF lemmatized: p=3.2488636697437614e-123, stat=580.5326796931913
# LLaMA 3.2 3B, Golden Description ROUGE 1: p=0.0, stat=2423.450039001743
# LLaMA 3.2 3B, Golden Description ROUGE 2: p=0.0, stat=3638.993178525902
# LLaMA 3.2 3B, Golden Description ROUGE L: p=0.0, stat=2851.801842209576
# LLaMA 3.2 3B, Golden Description ROUGE sum: p=0.0, stat=1691.2979470587684
# LLaMA 3.2 3B, KC: p=2.711158213071091e-21, stat=106.1148521950014
# LLaMA 3.2 3B, KC CompressionRatio: p=1.5522936154798049e-121, stat=572.7591805243402
# LLaMA 3.2 3B, NamedEntityDensity: p=0.00016681084065846318, stat=24.594780246782587
# LLaMA 3.2 3B, StringLength: p=5.718386807027103e-39, stat=189.22590467930465
# LLaMA 3.2 3B, TopicConsistency: p=0.04002286850991112, stat=11.642870701028448
# WizardLM-2, KC CompressionRatio: p=2.6176734601629814e-122, stat=576.3378672348142
# WizardLM-2, FRE: p=0.13586525664907614, stat=8.393003800814036
# WizardLM-2, Golden Description TF-IDF stemmed: p=4.2479304878219275e-18, stat=90.9478528830272
# WizardLM-2, Golden Description TF-IDF lemmatized: p=4.82151107332243e-13, stat=66.76494095138146
# WizardLM-2, TopicConsistency: p=3.9360071027212564e-10, stat=52.66735314913533
# WizardLM-2, Golden Description ROUGE 1: p=8.427271020109152e-185, stat=865.3410318549337
# WizardLM-2, Golden Description ROUGE 2: p=7.179956951625076e-59, stat=282.061253698991
# WizardLM-2, Golden Description ROUGE L: p=7.078143217779698e-80, stat=379.68458867174115
# WizardLM-2, Golden Description ROUGE sum: p=1.713252336698785e-110, stat=521.6254670868799
# WizardLM-2, StringLength: p=3.338322644209458e-238, stat=1112.0179480365134
# WizardLM-2, Golden Description BLEU: p=1.3133907068536072e-161, stat=758.1388770593857
# WizardLM-2, Golden Description BLEU brevity penalty: p=2.8309382561348356e-197, stat=922.9778157316235
# WizardLM-2, Golden Description BLEU length ratio: p=6.212058829443e-195, stat=912.160416018993
# WizardLM-2, Golden Description BLEU translation length: p=1.1450812738074971e-200, stat=938.6540082314532
# WizardLM-2, Golden Description BLEU reference length: p=0.9999985292217558, stat=0.015052652381410125
# WizardLM-2, Golden Description BLEU precision 1: p=3.3030411677679436e-28, stat=138.74732011914588
# WizardLM-2, Golden Description BLEU precision 2: p=1.7563605096902513e-21, stat=107.00778801350216
# WizardLM-2, Golden Description BLEU precision 3: p=6.78585349647563e-15, stat=75.65644219786942
# WizardLM-2, Golden Description BLEU precision 4: p=5.4302914182796596e-14, stat=71.32484111389537
# WizardLM-2, KC: p=2.3971114794701556e-223, stat=1043.4121173834978
# WizardLM-2, NamedEntityDensity: p=0.004895408557741713, stat=16.79987179736181
# LLaMA 3.2 1B, FRE: p=4.455863750519819e-82, stat=389.8997437715995
# LLaMA 3.2 1B, Golden Description BLEU: p=1.4433133286198205e-210, stat=984.3851928912657
# LLaMA 3.2 1B, Golden Description BLEU brevity penalty: p=1.4261716697371748e-104, stat=494.1998531537821
# LLaMA 3.2 1B, Golden Description BLEU length ratio: p=3.281979372793136e-105, stat=497.1559364900672
# LLaMA 3.2 1B, Golden Description BLEU translation length: p=3.980407641836238e-105, stat=496.76772734958985
# LLaMA 3.2 1B, Golden Description BLEU reference length: p=0.7873523368305684, stat=2.427631026146699
# LLaMA 3.2 1B, Golden Description BLEU precision 1: p=2.1570382852787712e-43, stat=209.9045123630774
# LLaMA 3.2 1B, Golden Description BLEU precision 2: p=7.252090695544831e-60, stat=286.6949722047056
# LLaMA 3.2 1B, Golden Description BLEU precision 3: p=2.72191321722158e-70, stat=335.17224375647294
# LLaMA 3.2 1B, Golden Description BLEU precision 4: p=1.1902637717032634e-68, stat=327.54760551872414
# LLaMA 3.2 1B, Golden Description TF-IDF stemmed: p=4.737398633776e-34, stat=166.19141647320794
# LLaMA 3.2 1B, Golden Description TF-IDF lemmatized: p=5.300953612166763e-25, stat=123.64525033409882
# LLaMA 3.2 1B, Golden Description ROUGE 1: p=1.6937305787578236e-250, stat=1168.7861665414978
# LLaMA 3.2 1B, Golden Description ROUGE 2: p=5.015082603619514e-239, stat=1115.8193750224239
# LLaMA 3.2 1B, Golden Description ROUGE L: p=3.8325365357323847e-228, stat=1065.5623434579018
# LLaMA 3.2 1B, Golden Description ROUGE sum: p=1.0478748895628131e-128, stat=605.9497328415356
# LLaMA 3.2 1B, KC: p=1.7843593662471508e-67, stat=322.0824991097159
# LLaMA 3.2 1B, KC CompressionRatio: p=1.4639407034270392e-76, stat=364.29217930564795
# LLaMA 3.2 1B, NamedEntityDensity: p=1.5249912556831182e-09, stat=49.796838747623035
# LLaMA 3.2 1B, StringLength: p=1.8297452771368573e-80, stat=382.41161601987545
# LLaMA 3.2 1B, TopicConsistency: p=0.3738369994083669, stat=5.357390331590168
# Gemini 2.0 Flash, Golden Description ROUGE 1: p=3.9031448160297264e-64, stat=306.55424385777
# Gemini 2.0 Flash, Golden Description ROUGE 2: p=1.140489275925872e-13, stat=69.77674926329007
# Gemini 2.0 Flash, Golden Description ROUGE L: p=1.0595912811527594e-36, stat=178.61067580177277
# Gemini 2.0 Flash, Golden Description ROUGE sum: p=3.927611267813379e-12, stat=62.371921435987204
# Gemini 2.0 Flash, NamedEntityDensity: p=8.926787276013719e-05, stat=25.999199891034156
# Gemini 2.0 Flash, TopicConsistency: p=2.159810049252945e-42, stat=205.22985537824547
# Gemini 2.0 Flash, KC CompressionRatio: p=1.194674846992593e-95, stat=452.8465068013352
# Gemini 2.0 Flash, Golden Description TF-IDF stemmed: p=0.13674689919839086, stat=8.374936857835564
# Gemini 2.0 Flash, Golden Description TF-IDF lemmatized: p=0.14164485531690102, stat=8.27642669614579
# Gemini 2.0 Flash, KC: p=2.130050802992773e-268, stat=1251.425419062494
# Gemini 2.0 Flash, FRE: p=6.701804475861509e-83, stat=393.71768678507465
# Gemini 2.0 Flash, Golden Description BLEU: p=3.4505010065846274e-81, stat=385.77422867586574
# Gemini 2.0 Flash, Golden Description BLEU brevity penalty: p=7.197545839399965e-111, stat=523.3699218754863
# Gemini 2.0 Flash, Golden Description BLEU length ratio: p=2.283919765484385e-111, stat=525.6787709286748
# Gemini 2.0 Flash, Golden Description BLEU translation length: p=2.2536990445439664e-150, stat=706.1897168779252
# Gemini 2.0 Flash, Golden Description BLEU reference length: p=1.0, stat=0.0
# Gemini 2.0 Flash, Golden Description BLEU precision 1: p=8.892866988049754e-83, stat=393.147616572508
# Gemini 2.0 Flash, Golden Description BLEU precision 2: p=2.8762575275758504e-32, stat=157.82603346810038
# Gemini 2.0 Flash, Golden Description BLEU precision 3: p=1.2116046542992509e-14, stat=74.45010801146165
# Gemini 2.0 Flash, Golden Description BLEU precision 4: p=1.3028713843122337e-07, stat=40.29381751296715
# Gemini 2.0 Flash, StringLength: p=4.125789957248882e-161, stat=755.8405016986801
# Mistral, FRE: p=2.909099112399241e-10, stat=53.30686835348837
# Mistral, Golden Description BLEU: p=1.3876760446685057e-73, stat=350.46826125951486
# Mistral, Golden Description BLEU brevity penalty: p=1.1536157861333379e-151, stat=712.1594129493684
# Mistral, Golden Description BLEU length ratio: p=2.701364758263374e-147, stat=691.9509057095081
# Mistral, Golden Description BLEU translation length: p=8.588056118778941e-169, stat=791.3530189571418
# Mistral, Golden Description BLEU reference length: p=0.9999978664703122, stat=0.01747365497277018
# Mistral, Golden Description BLEU precision 1: p=1.0619476106353923e-89, stat=425.263348187626
# Mistral, Golden Description BLEU precision 2: p=1.6537085145145064e-62, stat=298.98693718733773
# Mistral, Golden Description BLEU precision 3: p=1.9740864140555108e-54, stat=261.3911348596824
# Mistral, Golden Description BLEU precision 4: p=1.4513704617542862e-56, stat=271.32776168152736
# Mistral, Golden Description TF-IDF stemmed: p=8.790684556295936e-27, stat=132.03793735033832
# Mistral, Golden Description TF-IDF lemmatized: p=1.476580605654606e-23, stat=116.82378507017711
# Mistral, Golden Description ROUGE 1: p=2.347500845869479e-109, stat=516.360061858616
# Mistral, Golden Description ROUGE 2: p=1.2171454997705125e-16, stat=84.00450035578028
# Mistral, Golden Description ROUGE L: p=1.042523026997609e-46, stat=225.38573514863944
# Mistral, Golden Description ROUGE sum: p=2.390791977513506e-56, stat=270.31843036854474
# Mistral, KC: p=2.010463064555646e-202, stat=946.7643247469998
# Mistral, KC CompressionRatio: p=8.236162210382009e-135, stat=634.1986387806271
# Mistral, NamedEntityDensity: p=0.03813485160873426, stat=11.766255822184197
# Mistral, StringLength: p=4.707690142282308e-218, stat=1018.9654132213776
# Mistral, TopicConsistency: p=2.9775297337831497e-28, stat=138.95933451327497
# Gemini 1.5 Flash, Golden Description ROUGE 1: p=0.0, stat=3000.0823875094234
# Gemini 1.5 Flash, Golden Description ROUGE 2: p=1.5653784780305254e-232, stat=1085.8302443020368
# Gemini 1.5 Flash, Golden Description ROUGE L: p=2.188923911078738e-208, stat=974.3111183448104
# Gemini 1.5 Flash, Golden Description ROUGE sum: p=2.1464833129239286e-208, stat=974.3503974861186
# Gemini 1.5 Flash, NamedEntityDensity: p=0.23653682826490777, stat=6.792481559627628
# Gemini 1.5 Flash, TopicConsistency: p=5.370083948362063e-146, stat=685.945487928317
# Gemini 1.5 Flash, KC CompressionRatio: p=1.5489976370894016e-77, stat=368.8212632734335
# Gemini 1.5 Flash, Golden Description TF-IDF stemmed: p=1.5855223199257358e-56, stat=271.14898762500525
# Gemini 1.5 Flash, Golden Description TF-IDF lemmatized: p=1.896756177571175e-16, stat=83.08498848179443
# Gemini 1.5 Flash, KC: p=0.0, stat=5756.4986602130675
# Gemini 1.5 Flash, FRE: p=0.024681135978981295, stat=12.864606117481397
# Gemini 1.5 Flash, Golden Description BLEU: p=0.0, stat=3037.1332658880056
# Gemini 1.5 Flash, Golden Description BLEU brevity penalty: p=0.0, stat=4562.785993723785
# Gemini 1.5 Flash, Golden Description BLEU length ratio: p=0.0, stat=4567.130587666462
# Gemini 1.5 Flash, Golden Description BLEU translation length: p=0.0, stat=4510.1416826700015
# Gemini 1.5 Flash, Golden Description BLEU reference length: p=1.0, stat=0.0
# Gemini 1.5 Flash, Golden Description BLEU precision 1: p=0.0, stat=1615.6836745510648
# Gemini 1.5 Flash, Golden Description BLEU precision 2: p=3.639585476822466e-20, stat=100.76857803115696
# Gemini 1.5 Flash, Golden Description BLEU precision 3: p=0.019311859896295885, stat=13.474981136619078
# Gemini 1.5 Flash, Golden Description BLEU precision 4: p=9.182029050162686e-21, stat=103.60464460135893
# Gemini 1.5 Flash, StringLength: p=0.0, stat=5071.610685604118
# Solar, FRE: p=3.17929339909921e-14, stat=72.44080685455711
# Solar, Golden Description BLEU: p=9.721863354143888e-85, stat=402.2480079599624
# Solar, Golden Description BLEU brevity penalty: p=0.0, stat=1706.5559355756873
# Solar, Golden Description BLEU length ratio: p=0.0, stat=1735.9566226085917
# Solar, Golden Description BLEU translation length: p=0.0, stat=2129.5492430604972
# Solar, Golden Description BLEU reference length: p=1.0, stat=0.0
# Solar, Golden Description BLEU precision 1: p=0.0, stat=1608.1698550620822
# Solar, Golden Description BLEU precision 2: p=1.0729582720911718e-272, stat=1271.2646644570073
# Solar, Golden Description BLEU precision 3: p=6.80274039317807e-207, stat=967.4168574856026
# Solar, Golden Description BLEU precision 4: p=5.649324764783211e-154, stat=722.8421969248124
# Solar, Golden Description TF-IDF stemmed: p=5.5695769632029966e-09, stat=47.042371165145596
# Solar, Golden Description TF-IDF lemmatized: p=4.224971195755372e-08, stat=42.71278707707097
# Solar, Golden Description ROUGE 1: p=3.44364407949401e-140, stat=659.0836060893506
# Solar, Golden Description ROUGE 2: p=1.464127207100167e-29, stat=145.1123369837113
# Solar, Golden Description ROUGE L: p=5.1131826268837465e-17, stat=85.8010484061099
# Solar, Golden Description ROUGE sum: p=1.1955027030826625e-16, stat=84.041679806765
# Solar, KC: p=0.0, stat=2810.7560515791592
# Solar, KC CompressionRatio: p=2.467587274554978e-146, stat=687.5074971646304
# Solar, NamedEntityDensity: p=6.911366447459739e-11, stat=56.34154503210652
# Solar, StringLength: p=0.0, stat=2699.39117095823
# Solar, TopicConsistency: p=0.006652494279516808, stat=16.068034037793097
# GPT-3.5 Turbo, FRE: p=3.9479511390756205e-98, stat=464.3462765509895
# GPT-3.5 Turbo, Golden Description BLEU: p=3.620507127600758e-101, stat=478.4241745006667
# GPT-3.5 Turbo, Golden Description BLEU brevity penalty: p=3.118578098684855e-130, stat=613.0135031698347
# GPT-3.5 Turbo, Golden Description BLEU length ratio: p=5.915353274905584e-132, stat=620.9821159838499
# GPT-3.5 Turbo, Golden Description BLEU translation length: p=6.553603985701569e-137, stat=643.911472495543
# GPT-3.5 Turbo, Golden Description BLEU reference length: p=0.9999997548279874, stat=0.007343521826521324
# GPT-3.5 Turbo, Golden Description BLEU precision 1: p=5.334342173823861e-13, stat=66.55355198208886
# GPT-3.5 Turbo, Golden Description BLEU precision 2: p=8.051821289105065e-14, stat=70.50323796238708
# GPT-3.5 Turbo, Golden Description BLEU precision 3: p=4.354727494855402e-06, stat=32.68068765458207
# GPT-3.5 Turbo, Golden Description BLEU precision 4: p=0.0013140936224706756, stat=19.883727574431134
# GPT-3.5 Turbo, Golden Description TF-IDF stemmed: p=9.140000443286372e-53, stat=253.63114418398618
# GPT-3.5 Turbo, Golden Description TF-IDF lemmatized: p=1.0102736484788091e-70, stat=337.17221324369166
# GPT-3.5 Turbo, Golden Description ROUGE 1: p=8.764680259218971e-96, stat=453.47007498783165
# GPT-3.5 Turbo, Golden Description ROUGE 2: p=7.779866969903626e-13, stat=65.76407008278316
# GPT-3.5 Turbo, Golden Description ROUGE L: p=9.44856778381501e-57, stat=272.1957333999266
# GPT-3.5 Turbo, Golden Description ROUGE sum: p=1.3193729859586841e-48, stat=234.23964219141612
# GPT-3.5 Turbo, KC: p=3.515518687096184e-198, stat=927.1633726045874
# GPT-3.5 Turbo, KC CompressionRatio: p=2.559405255133851e-93, stat=442.04023089346964
# GPT-3.5 Turbo, NamedEntityDensity: p=4.23516666380894e-06, stat=32.74162447615988
# GPT-3.5 Turbo, StringLength: p=8.100479482293995e-198, stat=925.4884876639397
# GPT-3.5 Turbo, TopicConsistency: p=1.6085543642841e-154, stat=725.3650206238025
# GPT-4o mini, Golden Description ROUGE 1: p=7.105722684422726e-60, stat=286.73617902393187
# GPT-4o mini, Golden Description ROUGE 2: p=1.0040676398991318e-09, stat=50.68358510383555
# GPT-4o mini, Golden Description ROUGE L: p=2.3042517585155277e-28, stat=139.48313668841413
# GPT-4o mini, Golden Description ROUGE sum: p=1.2119104869824296e-38, stat=187.69967326625317
# GPT-4o mini, NamedEntityDensity: p=8.556550396298782e-19, stat=94.25743216654173
# GPT-4o mini, TopicConsistency: p=2.231876826925219e-30, stat=148.9516218670167
# GPT-4o mini, KC CompressionRatio: p=9.85535279317419e-96, stat=453.23394993801946
# GPT-4o mini, Golden Description TF-IDF stemmed: p=5.558815435309271e-59, stat=282.57852829255717
# GPT-4o mini, Golden Description TF-IDF lemmatized: p=4.603086022219913e-44, stat=213.03773220712173
# GPT-4o mini, KC: p=2.4955502432596764e-71, stat=339.99365962956904
# GPT-4o mini, FRE: p=1.5457317293905518e-36, stat=177.84266415075984
# GPT-4o mini, Golden Description BLEU: p=6.752310290217576e-45, stat=216.93040575781197
# GPT-4o mini, Golden Description BLEU brevity penalty: p=2.182277699160998e-57, stat=275.15896768068825
# GPT-4o mini, Golden Description BLEU length ratio: p=1.555637807491472e-58, stat=280.4983478607578
# GPT-4o mini, Golden Description BLEU translation length: p=5.906352503626097e-68, stat=324.31431981113934
# GPT-4o mini, Golden Description BLEU reference length: p=1.0, stat=0.0
# GPT-4o mini, Golden Description BLEU precision 1: p=9.297305492864292e-11, stat=55.71611535222747
# GPT-4o mini, Golden Description BLEU precision 2: p=3.0921771288796403e-09, stat=48.2948526501451
# GPT-4o mini, Golden Description BLEU precision 3: p=1.2262632532588694e-10, stat=55.13195080920911
# GPT-4o mini, Golden Description BLEU precision 4: p=1.991383220291798e-13, stat=68.61298444577373
# GPT-4o mini, StringLength: p=3.049307258669224e-82, stat=390.66420292304235
# GPT-4o, FRE: p=8.98796289527937e-07, stat=36.119846993122934
# GPT-4o, Golden Description BLEU: p=2.5356209738855964e-93, stat=442.05903058720287
# GPT-4o, Golden Description BLEU brevity penalty: p=1.5282600234832834e-107, stat=507.9591462931585
# GPT-4o, Golden Description BLEU length ratio: p=3.673470344540071e-104, stat=492.2960344891305
# GPT-4o, Golden Description BLEU translation length: p=1.8489208115823427e-141, stat=664.9591779562165
# GPT-4o, Golden Description BLEU reference length: p=1.0, stat=0.0
# GPT-4o, Golden Description BLEU precision 1: p=2.171276534459152e-36, stat=177.15147708855383
# GPT-4o, Golden Description BLEU precision 2: p=1.2659599334658167e-25, stat=126.57858743118662
# GPT-4o, Golden Description BLEU precision 3: p=1.334915506654561e-19, stat=98.09020319424279
# GPT-4o, Golden Description BLEU precision 4: p=4.5909167659975687e-26, stat=128.6553210960651
# GPT-4o, Golden Description TF-IDF stemmed: p=3.894045732353482e-05, stat=27.849996924269362
# GPT-4o, Golden Description TF-IDF lemmatized: p=7.535985671239931e-05, stat=26.378168082716
# GPT-4o, Golden Description ROUGE 1: p=4.492172191270646e-86, stat=408.44288409902504
# GPT-4o, Golden Description ROUGE 2: p=2.9662028723983156e-32, stat=157.76326990839118
# GPT-4o, Golden Description ROUGE L: p=1.7359668527759985e-37, stat=182.28896351080823
# GPT-4o, Golden Description ROUGE sum: p=1.4579127802846807e-71, stat=341.07816466017505
# GPT-4o, KC: p=4.255103469954961e-160, stat=751.155002762294
# GPT-4o, KC CompressionRatio: p=2.3802290909077262e-64, stat=307.5531114259686
# GPT-4o, NamedEntityDensity: p=0.0009663831269183721, stat=20.593842066721884
# GPT-4o, StringLength: p=8.634482628826112e-183, stat=856.0497996544052
# GPT-4o, TopicConsistency: p=2.5291867888216488e-14, stat=72.91747091730109
# Gemma 2 2B, Golden Description ROUGE 1: p=2.773978754188083e-51, stat=246.723379299283
# Gemma 2 2B, Golden Description ROUGE 2: p=2.1596788564557924e-57, stat=275.1800147103855
# Gemma 2 2B, Golden Description ROUGE L: p=3.5261864141231916e-60, stat=288.1522226001172
# Gemma 2 2B, Golden Description ROUGE sum: p=4.464974514605864e-40, stat=194.40610407850872
# Gemma 2 2B, NamedEntityDensity: p=1.271870882996508e-19, stat=98.1899488817364
# Gemma 2 2B, TopicConsistency: p=3.6774193576398194e-219, stat=1024.079545464268
# Gemma 2 2B, KC CompressionRatio: p=1.155461568327856e-05, stat=30.53805360008158
# Gemma 2 2B, Golden Description TF-IDF stemmed: p=9.3264281509943e-45, stat=216.2754835021551
# Gemma 2 2B, Golden Description TF-IDF lemmatized: p=7.964172241390845e-36, stat=174.50760114397417
# Gemma 2 2B, KC: p=5.29082103624995e-101, stat=477.66068448486556
# Gemma 2 2B, FRE: p=2.2520060021590633e-55, stat=265.7824769220074
# Gemma 2 2B, Golden Description BLEU: p=5.166595475724731e-104, stat=491.60971188782054
# Gemma 2 2B, Golden Description BLEU brevity penalty: p=1.3884216678574208e-100, stat=475.71895703166103
# Gemma 2 2B, Golden Description BLEU length ratio: p=7.000314077832113e-100, stat=472.46286465021376
# Gemma 2 2B, Golden Description BLEU translation length: p=2.1589223115913874e-95, stat=451.6551687147372
# Gemma 2 2B, Golden Description BLEU reference length: p=0.40033715797702185, stat=5.129029976187049
# Gemma 2 2B, Golden Description BLEU precision 1: p=5.0626412323614324e-145, stat=681.4385095064991
# Gemma 2 2B, Golden Description BLEU precision 2: p=9.441586383718737e-75, stat=355.8894040490829
# Gemma 2 2B, Golden Description BLEU precision 3: p=1.1044862728343119e-54, stat=262.56593640455833
# Gemma 2 2B, Golden Description BLEU precision 4: p=1.8945271310183484e-36, stat=177.42880928006443
# Gemma 2 2B, StringLength: p=1.972988665294309e-81, stat=386.9008720705699
# Gemma 2 27B, Golden Description ROUGE 1: p=1.5946235481947407e-136, stat=642.1247471002032
# Gemma 2 27B, Golden Description ROUGE 2: p=1.2920908968445378e-77, stat=369.1869124894736
# Gemma 2 27B, Golden Description ROUGE L: p=6.097107882358658e-71, stat=338.19119611546
# Gemma 2 27B, Golden Description ROUGE sum: p=2.2696736113292538e-82, stat=391.2593028527522
# Gemma 2 27B, NamedEntityDensity: p=0.18545253899547637, stat=7.50899927194972
# Gemma 2 27B, TopicConsistency: p=1.4692778747903352e-06, stat=35.05176793054848
# Gemma 2 27B, KC CompressionRatio: p=1.1002471571970629e-35, stat=173.8500714885913
# Gemma 2 27B, Golden Description TF-IDF stemmed: p=3.701249995553885e-14, stat=72.1239931863508
# Gemma 2 27B, Golden Description TF-IDF lemmatized: p=1.0649633873548537e-13, stat=69.91975188880217
# Gemma 2 27B, KC: p=3.334394492497184e-220, stat=1028.8946009997394
# Gemma 2 27B, FRE: p=8.596110610793061e-12, stat=60.7277832388164
# Gemma 2 27B, Golden Description BLEU: p=9.505151997976333e-174, stat=814.2613453835388
# Gemma 2 27B, Golden Description BLEU brevity penalty: p=1.5779082085188016e-194, stat=910.2898856886225
# Gemma 2 27B, Golden Description BLEU length ratio: p=8.072513633869639e-195, stat=911.6347453595831
# Gemma 2 27B, Golden Description BLEU translation length: p=2.3940110800387757e-198, stat=927.9342943360772
# Gemma 2 27B, Golden Description BLEU reference length: p=0.9999995633550292, stat=0.009253070248480523
# Gemma 2 27B, Golden Description BLEU precision 1: p=2.7773916405527648e-36, stat=176.6506858770998
# Gemma 2 27B, Golden Description BLEU precision 2: p=0.009335911843306916, stat=15.25257725600146
# Gemma 2 27B, Golden Description BLEU precision 3: p=2.0867350517846575e-06, stat=34.28768650191316
# Gemma 2 27B, Golden Description BLEU precision 4: p=5.822093930405712e-15, stat=75.97508282915153
# Gemma 2 27B, StringLength: p=6.630249417343835e-195, stat=912.0296868806266
# Gemini 1.5 Flash-8B, Golden Description ROUGE 1: p=0.0, stat=3697.3302565294807
# Gemini 1.5 Flash-8B, Golden Description ROUGE 2: p=0.0, stat=2160.766662189243
# Gemini 1.5 Flash-8B, Golden Description ROUGE L: p=0.0, stat=2677.201060514256
# Gemini 1.5 Flash-8B, Golden Description ROUGE sum: p=0.0, stat=2706.1105410958694
# Gemini 1.5 Flash-8B, NamedEntityDensity: p=1.1768410071871675e-67, stat=322.9227181557377
# Gemini 1.5 Flash-8B, TopicConsistency: p=1.4763340800559186e-54, stat=261.97890925200517
# Gemini 1.5 Flash-8B, KC CompressionRatio: p=1.4513683915971253e-159, stat=748.6912272038458
# Gemini 1.5 Flash-8B, Golden Description TF-IDF stemmed: p=1.1077146278264183e-70, stat=336.9864138830453
# Gemini 1.5 Flash-8B, Golden Description TF-IDF lemmatized: p=8.222060301343137e-34, stat=165.06865903292055
# Gemini 1.5 Flash-8B, KC: p=0.0, stat=3837.110630510725
# Gemini 1.5 Flash-8B, FRE: p=5.85062434097179e-19, stat=95.04208001334317
# Gemini 1.5 Flash-8B, Golden Description BLEU: p=0.0, stat=3483.560538052888
# Gemini 1.5 Flash-8B, Golden Description BLEU brevity penalty: p=0.0, stat=3800.067375885567
# Gemini 1.5 Flash-8B, Golden Description BLEU length ratio: p=0.0, stat=3804.4939947868534
# Gemini 1.5 Flash-8B, Golden Description BLEU translation length: p=0.0, stat=3533.980120432651
# Gemini 1.5 Flash-8B, Golden Description BLEU reference length: p=0.999147292091702, stat=0.1968592337757935
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 1: p=1.2139300551565302e-35, stat=173.65000008398306
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 2: p=1.268351320375408e-30, stat=150.10469891445027
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 3: p=1.261758579599273e-17, stat=88.69700818019263
# Gemini 1.5 Flash-8B, Golden Description BLEU precision 4: p=4.59630408942567e-12, stat=62.04207485459249
# Gemini 1.5 Flash-8B, StringLength: p=0.0, stat=3624.74362185283

# %%
# Create heatmaps of correlation between topics

save_dir = r"plots/heatmaps/per_topics"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for model, model_data in results.items():
    metric_pivots = []

    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)

        df_pivot = df.pivot_table(index='position', columns='topic', values='score', aggfunc='mean')

        plt.figure(figsize=(12, 6))
        plt.clf()
        ax =  sns.heatmap(df_pivot.corr('spearman'), annot=True, fmt='.2f', linewidths=0.5)
        
        plt.title(f"{model}-{metric}")

        plt.savefig(f'{save_dir}/{model}_{metric}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
# Create heatmaps of correlation between positions

save_dir = r"plots/heatmaps/per_position"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

for model, model_data in results.items():
    metric_pivots = []

    for metric, metric_data in model_data.items():
        df = pd.DataFrame(metric_data)

        df_pivot = df.pivot_table(index='topic', columns='position', values='score', aggfunc='mean')

        plt.figure(figsize=(12, 6))
        plt.clf()
        ax =  sns.heatmap(df_pivot.corr('spearman'), annot=True, fmt='.2f', linewidths=0.5)
        
        plt.title(f"{model}-{metric}")

        plt.savefig(f'{save_dir}/{model}_{metric}.png',dpi=600,bbox_inches='tight', transparent=False,pad_inches=0)
        plt.close()

# %%
missing_positions = {}
missing_topics = {}

for model, model_data in results.items():
    
    missing_positions_per_model = defaultdict(int)
    missing_topics_per_model = defaultdict(int)

    metric = "MissingTopics"
    metric_data = model_data[metric]

    df = pd.DataFrame(metric_data)

    for pos in range(1, 7):
        missing_positions_per_model[pos] += np.sum(df[df["position"]==pos]["score"].values)

    # Take one prompt to get all topics
    for pos in df["prompt"][0]:
        missing_topics_per_model[pos] += np.sum(df[df["topic"]==pos]["score"].values)

    model = model.replace(" ", "\n", 1)

    missing_positions[model] = missing_positions_per_model
    missing_topics[model] = missing_topics_per_model

# %%
df_missing_abs = pd.DataFrame.from_dict(missing_positions, orient='index')

df_missing_rel = df_missing_abs.div(df_missing_abs.sum(axis=1), axis=0)

ax = df_missing_rel.plot(kind='bar', stacked=True, figsize=(6, 5), color=["#4C72B0", "#937860", "#55A868", "#C44E52",  "#8172B3", "#DD8452"])
plt.ylabel("Percentage of missing position per ranking position")

for i, model in enumerate(df_missing_abs.index):
    total = df_missing_abs.loc[model].sum()
    ax.text(i, 1.02, str(total), ha='center', va='bottom', fontsize=10, color='black')

plt.legend(title="", bbox_to_anchor=(0.5, -0.3), loc='center', ncol=6, fontsize=8, frameon=False,
            markerscale=5)
plt.tight_layout()
ax.set_ylim(0, 1.1)
plt.show()

# %%
# Filter out the models with zero missing positions / topics

missing_positions = {}
missing_topics = {}

for model, model_data in results.items():
    if model in ["Gemini 2.0 Flash", "Solar", "Gemini 1.5 Flash", "GPT-4o mini", "GPT-4o", "WizardLM-2"]:
        continue
    
    missing_positions_per_model = defaultdict(int)
    missing_topics_per_model = defaultdict(int)

    metric = "MissingTopics"
    metric_data = model_data[metric]

    df = pd.DataFrame(metric_data)

    for pos in range(1, 7):
        missing_positions_per_model[pos] += np.sum(df[df["position"]==pos]["score"].values)

    # Take one prompt to get all topics
    for pos in df["prompt"][0]:
        missing_topics_per_model[pos] += np.sum(df[df["topic"]==pos]["score"].values)

    model = model.replace(" ", "\n", 1)

    missing_positions[model] = missing_positions_per_model
    missing_topics[model] = missing_topics_per_model

# %%
df_missing_abs = pd.DataFrame.from_dict(missing_positions, orient='index')

df_missing_rel = df_missing_abs.div(df_missing_abs.sum(axis=1), axis=0)

ax = df_missing_rel.plot(kind='bar', stacked=True, figsize=(6, 5), color=["#4C72B0", "#937860", "#55A868", "#C44E52",  "#8172B3", "#DD8452"])
plt.ylabel("Percentage of missing position per ranking position")

for i, model in enumerate(df_missing_abs.index):
    total = df_missing_abs.loc[model].sum()
    ax.text(i, 1.02, str(total), ha='center', va='bottom', fontsize=10, color='black')

plt.legend(title="", bbox_to_anchor=(0.5, -0.3), loc='center', ncol=6, fontsize=8, frameon=False,
            markerscale=5)
plt.tight_layout()
ax.set_ylim(0, 1.1)
plt.show()

# %%
df_missing_abs = pd.DataFrame.from_dict(missing_topics, orient='index')

df_missing_rel = df_missing_abs.div(df_missing_abs.sum(axis=1), axis=0)

ax = df_missing_rel.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.ylabel("Percentage")
plt.title("Missing Topics")

for i, model in enumerate(df_missing_abs.index):
    cumulative = 0 
    for pos in df_missing_abs.columns:
        abs_count = df_missing_abs.loc[model, pos]
        rel_val = df_missing_rel.loc[model, pos]
        
        if abs_count > 0:
            y = cumulative + rel_val / 2
            ax.text(i, y, str(abs_count), ha='center', va='center', fontsize=8, color='black', rotation=90)
        
        cumulative += rel_val

plt.legend(title="Missing Topics", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_missing_abs = pd.DataFrame.from_dict(missing_positions, orient='index')

df_missing_rel = df_missing_abs.div(df_missing_abs.sum(axis=1), axis=0)

ax = df_missing_rel.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.ylabel("Percentage")
plt.title("Missing Positions")


for i, model in enumerate(df_missing_abs.index):
    cumulative = 0 
    for pos in df_missing_abs.columns:
        abs_count = df_missing_abs.loc[model, pos]
        rel_val = df_missing_rel.loc[model, pos]
        
        if abs_count > 0:
            y = cumulative + rel_val / 2
            ax.text(i, y, str(abs_count), ha='center', va='center', fontsize=8, color='black', rotation=90)
        
        cumulative += rel_val

plt.legend(title="Missing Positions", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
df_missing_abs = pd.DataFrame.from_dict(missing_topics, orient='index')

df_missing_rel = df_missing_abs.div(df_missing_abs.sum(axis=1), axis=0)

ax = df_missing_rel.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.ylabel("Percentage")
plt.title("Missing Topics")

for i, model in enumerate(df_missing_abs.index):
    total = df_missing_abs.loc[model].sum()
    ax.text(i, 1.02, str(total), ha='center', va='bottom', fontsize=10, color='black')

plt.legend(title="Missing Topics", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
ax.set_ylim(0, 1.1)
plt.show()
